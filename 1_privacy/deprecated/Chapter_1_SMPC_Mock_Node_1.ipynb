# %% [markdown]
# # Mock PyGrid Node #1
#
# Make sure to download the contents of the [PyGrid repo](https://github.com/OpenMined/PyGrid), specifically that for [commit `048be4ac52a53b5ca947b920e41de9a9e76a532a`](https://github.com/OpenMined/PyGrid/commit/048be4ac52a53b5ca947b920e41de9a9e76a532a).
#
#
# | Chapter  | Colab   | Kaggle          | Gradient      | Studio Lab             | Binder             |
# |:---------|:--------|:----------------|:--------------|:-----------------------|:-------------------|
# | [Chapter 1: SMPC Mock Node #1](1_privacy/deprecated/Chapter_1_SCMP_Mock_Node_1.ipynb)                         | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/matthew-mcateer/practicing_trustworthy_machine_learning/blob/main/1_privacy/deprecated/Chapter_1_SCMP_Mock_Node_1.ipynb)       | [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/matthew-mcateer/practicing_trustworthy_machine_learning/blob/main/1_privacy/deprecated/Chapter_1_SCMP_Mock_Node_1.ipynb)       | [![Gradient](https://assets.paperspace.io/img/gradient-badge.svg)](https://console.paperspace.com/github/matthew-mcateer/practicing_trustworthy_machine_learning/blob/main/1_privacy/deprecated/Chapter_1_SCMP_Mock_Node_1.ipynb)       | [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/matthew-mcateer/practicing_trustworthy_machine_learning/blob/main/1_privacy/deprecated/Chapter_1_SCMP_Mock_Node_1.ipynb)       | [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/matthew-mcateer/practicing_trustworthy_machine_learning/HEAD?urlpath=https%3A%2F%2Fgithub.com%2Fmatthew-mcateer%2Fpracticing_trustworthy_machine_learning%2Fblob%2Fmain%2F1_privacy%2Fdeprecated%2FChapter_1_SCMP_Mock_Node_1.ipynb)              |

# %%
# !unzip -qq PyGrid-048be4ac52a53b5ca947b920e41de9a9e76a532a.zip

# %%
# %cd PyGrid-048be4ac52a53b5ca947b920e41de9a9e76a532a/apps/node
# Out:
# /content/PyGrid-048be4ac52a53b5ca947b920e41de9a9e76a532a/apps/node

# %%
# !pip -qq install poetry
# Out:
#      |████████████████████████████████| 175 kB 14.7 MB/s
#      |████████████████████████████████| 40 kB 5.2 MB/s
#      |████████████████████████████████| 91 kB 11.3 MB/s
#      |████████████████████████████████| 5.6 MB 67.1 MB/s
#      |████████████████████████████████| 424 kB 64.7 MB/s
#      |████████████████████████████████| 54 kB 2.4 MB/s
#      |████████████████████████████████| 54 kB 2.2 MB/s
#      |████████████████████████████████| 3.5 MB 67.1 MB/s
#      |████████████████████████████████| 496 kB 70.8 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
# !poetry --version
# Out:
# Poetry version 1.1.11

# %%
# !poetry install
# Out:
# Creating virtualenv openmined.gridnode-R1wZvcwx-py3.7 in /root/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
#
# Package operations: 134 installs, 0 updates, 0 removals
#
#   • Installing decorator (4.4.2): Pending...
#   • Installing ipython-genutils (0.2.0): Pending...
#   • Installing six (1.15.0): Pending...
#   • Installing zipp (3.1.0): Pending...
#   • Installing ipython-genutils (0.2.0): Pending...
#   • Installing six (1.15.0): Pending...
#   • Installing zipp (3.1.0): Pending...
#   • Installing decorator (4.4.2): Downloading... 0%
#   • Installing ipython-genutils (0.2.0): Pending...
#   • Installing six (1.15.0): Pending...
#   • Installing zipp (3.1.0): Pending...
#   • Installing ipython-genutils (0.2.0): Pending...
#   • Installing six (1.15.0): Pending...
#   • Installing zipp (3.1.0): Pending...
#   • Installing decorator (4.4.2): Downloading... 100%
#   • Installing ipython-genutils (0.2.0): Pending...
# ...

# %%
# !wget "https://raw.githubusercontent.com/facebookresearch/CrypTen/b1466440bde4db3e6e1fcb1740584d35a16eda9e/tutorials/mnist_utils.py" -O "mnist_utils.py"
# !python "mnist_utils.py" --option features --reduced 100 --binary
# Out:
# --2021-11-06 22:51:33--  https://raw.githubusercontent.com/facebookresearch/CrypTen/b1466440bde4db3e6e1fcb1740584d35a16eda9e/tutorials/mnist_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7401 (7.2K) [text/plain]
# Saving to: ‘mnist_utils.py’
#
# mnist_utils.py      100%[===================>]   7.23K  --.-KB/s    in 0s
#
# 2021-11-06 22:51:33 (82.4 MB/s) - ‘mnist_utils.py’ saved [7401/7401]
#
# ...
# 9913344it [00:00, 96301633.28it/s]
# Extracting /tmp/MNIST/raw/train-images-idx3-ubyte.gz to /tmp/MNIST/raw
#
# ...
# 29696it [00:00, 70890183.03it/s]
# Extracting /tmp/MNIST/raw/train-labels-idx1-ubyte.gz to /tmp/MNIST/raw
#
# ...
# 1649664it [00:00, 41294065.46it/s]
# Extracting /tmp/MNIST/raw/t10k-images-idx3-ubyte.gz to /tmp/MNIST/raw
#
# ...

# %%
# !./run.sh --id ALICE --port 3000 --start_local_db
# Out:
# WARNING:root:Using default secrect key, this is not safe and should be used only for testing and development. To define a secrete key please define the environment variable SECRET_KEY.
